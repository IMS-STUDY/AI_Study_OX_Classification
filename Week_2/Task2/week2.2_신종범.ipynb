# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers
import os
from sklearn.model_selection import train_test_split
# from tensorflow.python.client import device_lib
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
Path_Data = './Dataset/'

def load_images():
    image_list = [] #이미지 리스트
    label_list = [] #클래스 리트트
    for imgclass in os.listdir(Path_Data):  #디렉토리안에 있는 모든 파일을 순서대로 읽음
        if imgclass.endswith(('png','jpg')): #사진일떄 True
            img_path = os.path.join(Path_Data,imgclass)
            img = cv2.imread(img_path)
            if img is None: //이미지가 없을때
                continue
            img = cv2.resize(img, (300,300))
            img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            img = img/255.0
            label = 1 if 'o' in imgclass.lower() else 0
            image_list.append(img)
            label_list.append(label)
            
    return np.array(image_list,dtype=np.float32), np.array(label_list,dtype=np.int32)

#os.listdir(Path)#디렉토리안에 있는 모든 파일을 순서대로 읽어와 리스트로 저장한다
#endswith() 튜플이나 문자열의 입력된 것으로 끝나는지 확인한다
#cv2.imread()
#cv2.resize()
#cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
x,y=load_images()
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=22)

# %%
# 모델 생성 1
model = keras.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(300,300,3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1,activation = 'sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=50,batch_size=8,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.5416 - loss: 1.0682 - val_accuracy: 0.8750 - val_loss: 0.3166
# Epoch 2/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.7828 - loss: 0.3936 - val_accuracy: 0.9306 - val_loss: 0.2713
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.8941 - loss: 0.2189 - val_accuracy: 0.8750 - val_loss: 0.3539
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9838 - loss: 0.0872 - val_accuracy: 0.8750 - val_loss: 0.5254
# Epoch 5/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.9675 - loss: 0.0788 - val_accuracy: 0.8750 - val_loss: 0.4663
# Epoch 6/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9837 - loss: 0.0583 - val_accuracy: 0.8472 - val_loss: 0.7083
# Epoch 7/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.9980 - loss: 0.0088 - val_accuracy: 0.8611 - val_loss: 0.8632
# Epoch 8/50
# ...

# %%
# 모델 생성 2 스트라이드 추가
model = keras.Sequential()
model.add(layers.Conv2D(32, (3, 3),strides=(2, 2), activation='relu', input_shape=(300,300,3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3),strides=(2, 2), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3),strides=(1, 1), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1,activation = 'sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=50,batch_size=8,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.4991 - loss: 0.7200 - val_accuracy: 0.7361 - val_loss: 0.6136
# Epoch 2/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7159 - loss: 0.5593 - val_accuracy: 0.7500 - val_loss: 0.4662
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8650 - loss: 0.3085 - val_accuracy: 0.8611 - val_loss: 0.2637
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9394 - loss: 0.1652 - val_accuracy: 0.9583 - val_loss: 0.2067
# Epoch 5/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9514 - loss: 0.1531 - val_accuracy: 0.9028 - val_loss: 0.2414
# Epoch 6/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9530 - loss: 0.1187 - val_accuracy: 0.9444 - val_loss: 0.1347
# Epoch 7/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9793 - loss: 0.0594 - val_accuracy: 0.9306 - val_loss: 0.1149
# Epoch 8/50
# ...

# %%
# 모델 생성 3 활성화 함수 변경
model = keras.Sequential()
model.add(layers.Conv2D(32, (3, 3),strides=(2, 2), activation='relu', input_shape=(300,300,3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3),strides=(2, 2), activation='tanh'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3),strides=(1, 1), activation='tanh'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())
model.add(layers.Dense(64,activation='tanh'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1,activation = 'sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=50,batch_size=8,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# C:\Users\JongBeom\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5458 - loss: 0.9252 - val_accuracy: 0.8333 - val_loss: 0.3838
# Epoch 2/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7596 - loss: 0.4088 - val_accuracy: 0.8333 - val_loss: 0.3533
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9013 - loss: 0.2436 - val_accuracy: 0.8750 - val_loss: 0.2512
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9228 - loss: 0.1600 - val_accuracy: 0.9167 - val_loss: 0.1811
# Epoch 5/50
# ...

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=50,batch_size=8,validation_data=(x_test,y_test))

# %%
model.summary()
